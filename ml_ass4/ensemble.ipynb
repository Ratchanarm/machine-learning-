# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('wdbc.data')

# %%
df.head()
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471  ...  25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  0.2654  \
# 0  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 1  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 2  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 3  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
# 4  0.08089  ...  15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355  0.1741
#
#    0.4601   0.1189
# 0  0.2750  0.08902
# 1  0.3613  0.08758
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df_encoded = df.copy()
df_encoded[df.columns[1]] = label_encoder.fit_transform(df[df.columns[1]])
display(df_encoded.head())
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  1  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  1  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  1  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  1  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471  ...  25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  0.2654  \
# 0  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 1  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 2  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 3  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
# 4  0.08089  ...  15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355  0.1741
#
#    0.4601   0.1189
# 0  0.2750  0.08902
# 1  0.3613  0.08758
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Assuming all columns except the first two (ID and encoded diagnosis) are features
numerical_cols = df_encoded.columns[2:]

scaler = StandardScaler()
df_scaled = df_encoded.copy()
df_scaled[numerical_cols] = scaler.fit_transform(df_encoded[numerical_cols])

display(df_scaled.head())
# Out:
#      842302  M     17.99     10.38     122.8      1001    0.1184    0.2776  \
# 0    842517  1  1.832084 -0.358327  1.689106  1.910392 -0.825266 -0.485498
# 1  84300903  1  1.582106  0.453860  1.569590  1.560576  0.946192  1.067960
# 2  84348301  1 -0.767117  0.250813 -0.590772 -0.762711  3.290559  3.438483
# 3  84358402  1  1.752545 -1.158844  1.779774  1.827915  0.283499  0.549886
# 4    843786  1 -0.474529 -0.841438 -0.385121 -0.503904  2.243076  1.261043
#
#      0.3001    0.1471  ...     25.38     17.33     184.6      2019    0.1622  \
# 0 -0.019278  0.555261  ...  1.813349 -0.371875  1.545063  1.899054 -0.373544
# 1  1.375494  2.051509  ...  1.518626 -0.026387  1.356695  1.463694  0.530042
# 2  1.930879  1.463170  ... -0.278773  0.131690 -0.246823 -0.547953  3.398711
# 3  1.383068  1.439844  ...  1.304847 -1.470265  1.347725  1.227507  0.222998
# 4  0.875648  0.833102  ... -0.162544 -0.316467 -0.111378 -0.241438  2.052104
#
#      0.6656    0.7119    0.2654    0.4601    0.1189
# ...

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
x_train,x_test,y_train,y_test=train_test_split(df_scaled.iloc[:,2:],df_scaled.iloc[:,1],test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],        # measure of impurity
    'max_depth': [None, 10, 20, 30],         # depth of each tree
    'min_samples_split': [2, 5, 10],         # minimum samples to split
    'min_samples_leaf': [1, 2, 4],           # minimum samples per leaf
}

# %%
grid_search = GridSearchCV(

    estimator=model,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy' # metric to optimize
)

# Fit model
grid_search.fit(x_train, y_train)

# Best parameters and score
print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)

# Evaluate on test set
best_rf = grid_search.best_estimator_
print("Test Accuracy:", best_rf.score(x_test, y_test))
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best CV Score: 0.9427106227106228
# Test Accuracy: 0.9122807017543859

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
param_grid={
    'n_estimators': [50, 75,100],       # number of weak learners
    'learning_rate': [0.001, 0.01, 0.1, 1],    # step size / shrinkage
    'estimator': [                             # try different weak learners
        DecisionTreeClassifier(max_depth=1),   # decision stump (default)
        DecisionTreeClassifier(max_depth=2),
        DecisionTreeClassifier(max_depth=3)
    ]
}
model1=AdaBoostClassifier()



grid_search = GridSearchCV(
    estimator=model1,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)

grid_search.fit(x_train,y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best Parameters: {'estimator': DecisionTreeClassifier(max_depth=2), 'learning_rate': 1, 'n_estimators': 75}
# Best CV Score: 0.977997557997558

# %%
from sklearn.ensemble import GradientBoostingClassifier
param_grid={
    'n_estimators': [50,75,100],
    'learning_rate': [0.001, 0.01, 0.1, 1],
    'max_depth': [1, 2, 3, 4],
    'subsample': [0.8, 0.9, 1.0]
}
model2=GradientBoostingClassifier()

grid_search = GridSearchCV(
    estimator=model2,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)
grid_search.fit(x_train,y_train)
print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# Best Parameters: {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 75, 'subsample': 0.8}
# Best CV Score: 0.977997557997558

# %%
from xgboost import XGBClassifier
model3=XGBClassifier()
param_grid={
    'n_estimators': [50,75,100],
    'learning_rate': [0.001, 0.01, 0.1,],
    'max_depth': [3, 4, 5, 6],
    'subsample': [0.8, 0.9,]
}

grid_search = GridSearchCV(
    estimator=model3,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)
grid_search.fit(x_train,y_train)
print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}
# Best CV Score: 0.9647619047619049

# %%
from sklearn.ensemble import RandomForestClassifier
model4=RandomForestClassifier()
param_grid={
    'n_estimators': [50,75,100],
    'max_depth': [None, 10, 20, 30],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2']
}
grid_search = GridSearchCV(
    estimator=model4,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)
grid_search.fit(x_train,y_train)
print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# Best Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# Best CV Score: 0.9647619047619049

# %%
# ==============================
# Random Forest with GridSearchCV
# ==============================
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt



# 3. Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# 4. Define Model
rf_model = RandomForestClassifier(random_state=42)

# 5. Define Hyperparameter Grid
param_grid = {
    'n_estimators': [50, 75, 100],
    'max_depth': [None, 10, 20, 30],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2']
}

# 6. GridSearchCV Setup
grid_search = GridSearchCV(
    estimator=rf_model,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)

# 7. Fit Model with Best Parameters
grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)

# 8. Evaluate on Test Data
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
y_proba = best_rf.predict_proba(X_test)[:, 1]

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("\nRandom Forest Test Results")
print("===========================")
print(f"Accuracy: {acc:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# 9. ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label=f'Random Forest (AUC = {roc_auc:.3f})')
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Random Forest")
plt.legend()
plt.show()
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# Best Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 75}
# Best CV Score: 0.9581684981684981
#
# Random Forest Test Results
# ...
# Accuracy: 0.9649
# F1 Score: 0.9545
# Confusion Matrix:
# [[68  0]
#  [ 4 42]]

# %% [markdown]
# # Task
# Add code to calculate and display the confusion matrix and ROC curve for the Decision Tree, AdaBoost, Gradient Boosting, and XGBoost models.

# %% [markdown]
# ## Decision tree
#
# ### Subtask:
# Add code to calculate and display the confusion matrix and ROC curve for the Decision Tree model.

# %% [markdown]
# **Reasoning**:
# Calculate and display the confusion matrix and ROC curve for the Decision Tree model.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Decision Tree Confusion Matrix
dt_cm = confusion_matrix(y_test, y_pred)
print("Decision Tree Confusion Matrix:")
print(dt_cm)

# Decision Tree ROC Curve
# Get predicted probabilities
y_proba_dt = model.predict_proba(x_test)[:, 1]

# Calculate ROC curve and AUC
fpr_dt, tpr_dt, thresholds_dt = roc_curve(y_test, y_proba_dt)
roc_auc_dt = auc(fpr_dt, tpr_dt)

# Plot ROC Curve
plt.figure(figsize=(6, 4))
plt.plot(fpr_dt, tpr_dt, label=f'Decision Tree (AUC = {roc_auc_dt:.3f})')
plt.plot([0, 1], [0, 1], '--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Decision Tree")
plt.legend()
plt.show()
# Out:
# Decision Tree Confusion Matrix:
# [[68  0]
#  [ 4 42]]

# %% [markdown]
# ## Adaboost
#
# ### Subtask:
# Add code to calculate and display the confusion matrix and ROC curve for the AdaBoost model.

# %% [markdown]
# **Reasoning**:
# Calculate and display the confusion matrix, ROC curve, and AUC for the AdaBoost model and then plot the ROC curve.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# AdaBoost Confusion Matrix
y_pred_ada = grid_search.best_estimator_.predict(x_test)
ada_cm = confusion_matrix(y_test, y_pred_ada)
print("AdaBoost Confusion Matrix:")
print(ada_cm)

# AdaBoost ROC Curve
# Get predicted probabilities
y_proba_ada = grid_search.best_estimator_.predict_proba(x_test)[:, 1]

# Calculate ROC curve and AUC
fpr_ada, tpr_ada, thresholds_ada = roc_curve(y_test, y_proba_ada)
roc_auc_ada = auc(fpr_ada, tpr_ada)

# Plot ROC Curve
plt.figure(figsize=(6, 4))
plt.plot(fpr_ada, tpr_ada, label=f'AdaBoost (AUC = {roc_auc_ada:.3f})')
plt.plot([0, 1], [0, 1], '--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - AdaBoost")
plt.legend()
plt.show()
# Out:
# AdaBoost Confusion Matrix:
# [[68  0]
#  [ 4 42]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## Gradient boosting
#
# ### Subtask:
# Add code to calculate and display the confusion matrix and ROC curve for the Gradient Boosting model.

# %% [markdown]
# **Reasoning**:
# Calculate and display the confusion matrix and ROC curve for the Gradient Boosting model.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc

# Gradient Boosting Confusion Matrix
y_pred_gb = grid_search.best_estimator_.predict(x_test)
gb_cm = confusion_matrix(y_test, y_pred_gb)
print("Gradient Boosting Confusion Matrix:")
print(gb_cm)

# Gradient Boosting ROC Curve
# Get predicted probabilities
y_proba_gb = grid_search.best_estimator_.predict_proba(x_test)[:, 1]

# Calculate ROC curve and AUC
fpr_gb, tpr_gb, thresholds_gb = roc_curve(y_test, y_proba_gb)
roc_auc_gb = auc(fpr_gb, tpr_gb)

# Plot ROC Curve
plt.figure(figsize=(6, 4))
plt.plot(fpr_gb, tpr_gb, label=f'Gradient Boosting (AUC = {roc_auc_gb:.3f})')
plt.plot([0, 1], [0, 1], '--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Gradient Boosting")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# Gradient Boosting Confusion Matrix:
# [[68  0]
#  [ 4 42]]

# %% [markdown]
# ## Xgboost
#
# ### Subtask:
# Add code to calculate and display the confusion matrix and ROC curve for the XGBoost model.

# %% [markdown]
# **Reasoning**:
# Calculate and display the confusion matrix and ROC curve for the XGBoost model as per the instructions.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc

# XGBoost Confusion Matrix
y_pred_xgb = grid_search.best_estimator_.predict(x_test)
xgb_cm = confusion_matrix(y_test, y_pred_xgb)
print("XGBoost Confusion Matrix:")
print(xgb_cm)

# XGBoost ROC Curve
# Get predicted probabilities
y_proba_xgb = grid_search.best_estimator_.predict_proba(x_test)[:, 1]

# Calculate ROC curve and AUC
fpr_xgb, tpr_xgb, thresholds_xgb = roc_curve(y_test, y_proba_xgb)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)

# Plot ROC Curve
plt.figure(figsize=(6, 4))
plt.plot(fpr_xgb, tpr_xgb, label=f'XGBoost (AUC = {roc_auc_xgb:.3f})')
plt.plot([0, 1], [0, 1], '--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - XGBoost")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# XGBoost Confusion Matrix:
# [[68  0]
#  [ 4 42]]

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The AdaBoost and Gradient Boosting models achieved identical confusion matrices:
#     ```
#     [[68  0]
#      [ 4 42]]
#     ```
#     This indicates that both models correctly classified 68 negative instances and 42 positive instances, with 0 false positives and 4 false negatives.
# *   For the Decision Tree, AdaBoost, Gradient Boosting, and XGBoost models, the confusion matrices were successfully calculated and printed.
# *   The ROC curves and AUC scores were calculated and plotted for all four models, providing a visual and quantitative measure of their performance in distinguishing between classes.
#
# ### Insights or Next Steps
#
# *   Compare the AUC scores obtained for each model to quantitatively assess their performance relative to each other.
# *   Consider further analysis based on the confusion matrix results, such as calculating precision, recall, and F1-score for each model.

# %% [markdown]
# ## Decision Tree Confusion Matrix Plot

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Assuming y_test and y_pred are available from previous steps
# y_pred for Decision Tree is from cell QXIwN7B2BEWf
# y_test is from cell 4s0vi6f9ASHB

disp = ConfusionMatrixDisplay(confusion_matrix=dt_cm)
disp.plot()
plt.title("Confusion Matrix - Decision Tree")
plt.show()

# %% [markdown]
# ## AdaBoost Confusion Matrix Plot

# %%
# Assuming y_test and y_pred_ada are available from previous steps
# y_pred_ada for AdaBoost is from cell 86181893
# y_test is from cell 4s0vi6f9ASHB

disp = ConfusionMatrixDisplay(confusion_matrix=ada_cm)
disp.plot()
plt.title("Confusion Matrix - AdaBoost")
plt.show()

# %% [markdown]
# ## Gradient Boosting Confusion Matrix Plot

# %%
# Assuming y_test and y_pred_gb are available from previous steps
# y_pred_gb for Gradient Boosting is from cell cd0f086c
# y_test is from cell 4s0vi6f9ASHB

disp = ConfusionMatrixDisplay(confusion_matrix=gb_cm)
disp.plot()
plt.title("Confusion Matrix - Gradient Boosting")
plt.show()

# %% [markdown]
# ## XGBoost Confusion Matrix Plot

# %%
# Assuming y_test and y_pred_xgb are available from previous steps
# y_pred_xgb for XGBoost is from cell a2445b39
# y_test is from cell 4s0vi6f9ASHB

disp = ConfusionMatrixDisplay(confusion_matrix=xgb_cm)
disp.plot()
plt.title("Confusion Matrix - XGBoost")
plt.show()
